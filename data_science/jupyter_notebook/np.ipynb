# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
array1 = np.array([1, 2, 3])
array2 = np.array([4, 5, 6])

# %%
plt.plot(array1, array2, color='#088a15', marker='.', markerfacecolor='#8a0824')

# %%
plt.show()
